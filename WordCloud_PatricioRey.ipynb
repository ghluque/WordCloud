# %% [markdown]
# <a href="https://colab.research.google.com/github/ghluque/WordCloud/blob/master/WordCloud_PatricioRey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Arrancamos con una libreria hecha para python que se llama wordcloud. La usamos para trabajar nuestro texto. Hace un histograma, aumenta el tamaño de las palabras mas usadas y las imprime.
# STOPWORDS es un diccionario que permite ignorar ciertas palabras de nuestro texto que no son importantes al momento de analizarlo. Ej: preposiciones.
#
# Luego esta Numpy que nos brinda metodos para trabajar con matrices y numeros complejos (entre otras)

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np

# %% [markdown]
# Como la idea es analizar las letras de Patricio Rey y sus redonditos de ricota, se me ocurrio la idea de crear un bloc de notas para luego analizarlas. Importando el archivo desde mi pc hasta la notebook.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print("".format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-6fbf2185-d909-47f1-8b20-06c7a6f0e4dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6fbf2185-d909-47f1-8b20-06c7a6f0e4dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PR.txt to PR (2).txt

# %% [markdown]
# En la primera linea le indicamos a Python abrir el archivo. UTF-8 permite ampliar la codificacion de caracteres. Como los necesarios para analizar texto en español.
# En la segunda linea creamos la variable text y que lea el archivo.
# Por ultimo le pedimos imprimir para que vean que estan TODAS las canciones.

# %%
with open("PR.txt", encoding='utf-8') as file:
  text = file.read()
  print(text)
# Out:
# Esta vez (¡por fin!) la prisión te va a gustar
# el reo semental se va a licuar esta prisión.
# ¡Gatas lindas!, ¡sirenas llenas!
# ¡camisa apretada!, ¡pezón radioactivo!
# Reclamando el botín para la prisión
# del Dios-prisión-feliz-prisión…
# el Dios Barbazul de esta prisión.
#
# Tu aullido esta vez (¡quiera Dios!)
# no se va a oir en la prisión.
# Puede la virgen labial brillar
# en risas pillas, manzanas firmes
# de viejas feas como monos, ¡puájj!
# de antiguas Lobas-pulpas que reviven
# el amor letal de esta Prisión.
#
# Esta vez (¡por fin!) la prisión te va a gustar
# el reo semental se va a licuar esta prisión.
# ¡Gatas lindas!, ¡sirenas llenas!
# ¡camisa apretada!, ¡pezón radioactivo!
# Reclamando el botín para la prisión
# del Dios-prisión-feliz-prisión…
# el Dios Barbazul de esta prisión.
#
# Tu aullido esta vez (¡quiera Dios!)
# no se va a oir en la prisión.
# Puede la virgen labial brillar
# en risas pillas, manzanas firmes
# de viejas feas como monos, ¡puájj!
# ...

# %% [markdown]
# PIL= Python image library. Sirve para darle a Python las herramientas para trabajar con imagenes. BytesIO nos permite trabajar sobre la imagen.

# %%
from PIL import Image
from io import BytesIO


uploaded = files.upload()
im = Image.open(BytesIO(uploaded['PRL.jpg']))
# Out:
#      <input type="file" id="files-fb776edb-bd08-44c9-aa80-b0819938bddd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb776edb-bd08-44c9-aa80-b0819938bddd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PRL.jpg to PRL (10).jpg

# %% [markdown]
# Con las siguientes lineas le pedimos a Python que nos muestre la imagen

# %%
import matplotlib.pyplot as plt

plt.imshow(im)
plt.show()

# %% [markdown]
# Generamos la wordcloud o nube de palabras

# %%
WordCloud_data = text

wordcloud = WordCloud().generate(WordCloud_data)
